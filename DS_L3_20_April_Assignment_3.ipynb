# %% [markdown]
# # **Assignment - 3: Improving Graphs**
#
# ---
# Course website: [SHALA-2020](https://shala2020.github.io/)
#
# This assignment will get you familiarized with improving plots/graphs in Python.

# %% [markdown]
# ---
# ## Part 1 - Importing packages and loading data
# ---

# %% [markdown]
# ###Import the following libraries:
#
# * ```numpy``` with an alias name ```np```,
# * ```pandas``` with an alias name ```pd```,
# * ```matplotlib.pyplot``` with an alias name ```plt```, and
# * ```seaborn``` with an alias name ```sns```.
#
# *You are free to use any other popular libraries*.

# %%
# Load the libraries with their aliases 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Using the files ```train.csv``` and ```moviesData.csv```,  peform the following:
#
# * Load these file as ```pandas``` dataframes and store it in variables named ```train``` and ```movies``` respectively.
# * Print the first ten rows of ```train``` and last ten rows of ```movies```.

# %%
# Load train.csv and movies.csv 
url_train = "../L2/train.csv"
train = pd.read_csv(url_train)
# Print the first ten rows of train
train.head(10)
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
# 5   32          0  Travel_Frequently       1005  Research & Development
# 6   59          0      Travel_Rarely       1324  Research & Development
# 7   30          0      Travel_Rarely       1358  Research & Development
# 8   38          0  Travel_Frequently        216  Research & Development
# 9   36          0      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
# 5                 2          2  Life Sciences              1               8
# 6                 3          3        Medical              1              10
# 7                24          1  Life Sciences              1              11
# 8                23          3  Life Sciences              1              12
# 9                27          3        Medical              1              13
#
#    ...  RelationshipSatisfaction StockOptionLevel  TotalWorkingYears  \
# 0  ...                         1                0                  8
# 1  ...                         4                1                 10
# 2  ...                         2                0                  7
# 3  ...                         3                0                  8
# 4  ...                         4                1                  6
# 5  ...                         3                0                  8
# 6  ...                         1                3                 12
# 7  ...                         2                1                  1
# 8  ...                         2                0                 10
# 9  ...                         2                2                 17
#
#    TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                      0                1              6                   4
# 1                      3                3             10                   7
# 2                      3                3              0                   0
# 3                      3                3              8                   7
# 4                      3                3              2                   2
# 5                      2                2              7                   7
# 6                      3                2              1                   0
# 7                      2                3              1                   0
# 8                      2                3              9                   7
# 9                      3                2              7                   7
#
#   YearsSinceLastPromotion  YearsWithCurrManager  ID
# 0                       0                     5   0
# 1                       1                     7   1
# 2                       0                     0   2
# 3                       3                     0   3
# 4                       2                     2   4
# 5                       3                     6   5
# 6                       0                     0   6
# 7                       0                     0   7
# 8                       1                     8   8
# 9                       7                     7   9
#
# [10 rows x 34 columns]

# %%
# Load movies.csv
url_movies = "../L2/moviesData.csv"
movies = pd.read_csv(url_movies)

# Print the last ten rows of movies 
movies.head(10)
# Out:
#    Unnamed: 0                   title    title_type        genre  runtime  \
# 0           1             Filly Brown  Feature Film        Drama     80.0
# 1           2                The Dish  Feature Film        Drama    101.0
# 2           3     Waiting for Guffman  Feature Film       Comedy     84.0
# 3           4    The Age of Innocence  Feature Film        Drama    139.0
# 4           5             Malevolence  Feature Film       Horror     90.0
# 5           6             Old Partner   Documentary  Documentary     78.0
# 6           7               Lady Jane  Feature Film        Drama    142.0
# 7           8            Mad Dog Time  Feature Film        Drama     93.0
# 8           9  Beauty Is Embarrassing   Documentary  Documentary     88.0
# 9          10    The Snowtown Murders  Feature Film        Drama    119.0
#
#   mpaa_rating                    studio  thtr_rel_year  thtr_rel_month  \
# 0           R       Indomina Media Inc.           2013               4
# 1       PG-13     Warner Bros. Pictures           2001               3
# 2           R    Sony Pictures Classics           1996               8
# 3          PG         Columbia Pictures           1993              10
# 4           R  Anchor Bay Entertainment           2004               9
# 5     Unrated        Shcalo Media Group           2009               1
# 6       PG-13      Paramount Home Video           1986               1
# 7           R        MGM/United Artists           1996              11
# 8     Unrated      Independent Pictures           2012               9
# 9     Unrated                 IFC Films           2012               3
#
#    thtr_rel_day  ...  best_actor_win  best_actress_win  best_dir_win  \
# 0            19  ...              no                no            no
# 1            14  ...              no                no            no
# 2            21  ...              no                no            no
# 3             1  ...             yes                no           yes
# 4            10  ...              no                no            no
# 5            15  ...              no                no            no
# 6             1  ...              no                no            no
# 7             8  ...             yes                no            no
# 8             7  ...              no                no            no
# 9             2  ...              no                no            no
#
#    top200_box           director             actor1              actor2  \
# 0          no   Michael D. Olmos     Gina Rodriguez        Jenni Rivera
# 1          no          Rob Sitch          Sam Neill    Kevin Harrington
# 2          no  Christopher Guest  Christopher Guest    Catherine O'Hara
# 3          no    Martin Scorsese   Daniel Day-Lewis   Michelle Pfeiffer
# 4          no        Stevan Mena      Samantha Dark  R. Brandon Johnson
# 5          no    Chung-ryoul Lee      Choi Won-kyun        Lee Sam-soon
# 6          no        Trevor Nunn         Cary Elwes           John Wood
# 7          no       Larry Bishop   Richard Dreyfuss       Jeff Goldblum
# 8          no      Neil Berkeley       Paul Reubens       Matt Groening
# 9          no      Justin Kurzel     Lucas Pittaway     Daniel Henshall
#
#                  actor3            actor4                actor5
# 0  Lou Diamond Phillips     Emilio Rivera   Joseph Julian Soria
# 1     Patrick Warburton          Tom Long        Genevieve Mooy
# 2          Parker Posey       Eugene Levy           Bob Balaban
# 3          Winona Ryder  Richard E. Grant          Alec McCowen
# 4       Brandon Johnson     Heather Magee        Richard Glover
# 5                   Moo               NaN                   NaN
# 6       Michael Hordern   Jill Bennett II  Helena Bonham Carter
# 7         Gabriel Byrne      Ellen Barkin            Diane Lane
# 8           Todd Oldham   Jonathan Dayton        Cliff Benjamin
# 9         Louise Harris       Craig Coyne         Richard Green
#
# [10 rows x 31 columns]

# %% [markdown]
# ---
# ## Part 2 - Drawing correlation and heatmap
# ---

# %% [markdown]
# ### Using the correlation matrix, peform the following:
#
# * Find the correlation matrix for the ```movies```.
# * Draw a **heatmap** with the correlation matrix and display the values of correlation coefficients for each pair of features. Make sure the values are properly visible. You might want to adjust the figure size for this.
# * Create a ```mask``` to remove the duplicate values from the **heatmap**.

# %%
# Find out the correlation matrix 
movies_corr = movies.corr()
print(movies_corr)
# Draw the heatmap 
plt.figure(figsize=(20,20))
sns.heatmap(movies_corr, cmap="coolwarm")
# Out:
#                 Unnamed: 0   runtime  thtr_rel_year  thtr_rel_month  \
# Unnamed: 0        1.000000 -0.045146      -0.000639        0.005468
# runtime          -0.045146  1.000000      -0.124754        0.215274
# thtr_rel_year    -0.000639 -0.124754       1.000000       -0.026465
# thtr_rel_month    0.005468  0.215274      -0.026465        1.000000
# thtr_rel_day      0.046227  0.033998       0.089811        0.105620
# dvd_rel_year     -0.000382 -0.088603       0.655967       -0.017549
# dvd_rel_month    -0.015944 -0.036916       0.038498       -0.168568
# dvd_rel_day       0.024857  0.021001      -0.014895        0.038263
# imdb_rating       0.027596  0.261153      -0.040544        0.081638
# imdb_num_votes    0.045508  0.342462       0.152530        0.101305
# critics_score     0.003937  0.169494      -0.096445        0.047717
# audience_score    0.012582  0.172237      -0.062610        0.034901
#
#                 thtr_rel_day  dvd_rel_year  dvd_rel_month  dvd_rel_day  \
# Unnamed: 0          0.046227     -0.000382      -0.015944     0.024857
# runtime             0.033998     -0.088603      -0.036916     0.021001
# thtr_rel_year       0.089811      0.655967       0.038498    -0.014895
# thtr_rel_month      0.105620     -0.017549      -0.168568     0.038263
# thtr_rel_day        1.000000      0.025283      -0.011816    -0.005932
# dvd_rel_year        0.025283      1.000000       0.000762    -0.074623
# dvd_rel_month      -0.011816      0.000762       1.000000    -0.023765
# dvd_rel_day        -0.005932     -0.074623      -0.023765     1.000000
# imdb_rating         0.035423     -0.024504       0.077333     0.020661
# imdb_num_votes      0.069750      0.083158       0.048846    -0.027787
# critics_score       0.023837      0.009554       0.041502    -0.024717
# audience_score      0.033812     -0.073794       0.070543     0.019294
#
#                 imdb_rating  imdb_num_votes  critics_score  audience_score
# Unnamed: 0         0.027596        0.045508       0.003937        0.012582
# runtime            0.261153        0.342462       0.169494        0.172237
# thtr_rel_year     -0.040544        0.152530      -0.096445       -0.062610
# thtr_rel_month     0.081638        0.101305       0.047717        0.034901
# thtr_rel_day       0.035423        0.069750       0.023837        0.033812
# dvd_rel_year      -0.024504        0.083158       0.009554       -0.073794
# dvd_rel_month      0.077333        0.048846       0.041502        0.070543
# dvd_rel_day        0.020661       -0.027787      -0.024717        0.019294
# imdb_rating        1.000000        0.327647       0.770764        0.865149
# imdb_num_votes     0.327647        1.000000       0.200657        0.288328
# critics_score      0.770764        0.200657       1.000000        0.710695
# audience_score     0.865149        0.288328       0.710695        1.000000

# %%
# Creating a mask for removing duplicates 
mask = np.zeros_like(movies_corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.set_style(style = 'white')

# Set up  matplotlib figure
f, ax = plt.subplots(figsize=(15, 15))

# Add diverging colormap
cmap = sns.diverging_palette(10, 250, as_cmap=True)

# Draw correlation plot
sns.heatmap(movies_corr, mask=mask, cmap=cmap, 
        square=True,
        linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)

# %% [markdown]
# ---
# ## Part 3 - Drawing plots and customizing these
# ---

# %% [markdown]
# ### Using a histogram, peform the following:
#
# * Draw a histogram of all the numeric features in ```train```. Please note that this can be done in a single command.
#
# * Find out whether there is any redundant features in ```train```, which can be dropped while building a model.

# %%
# Draw a histogram 
print(train.plot.hist(grid=True))
# Find out the redundant features 
print(train.corr().abs())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
#                                Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.000000   0.168641   0.010270          0.022883
# Attrition                 0.168641   1.000000   0.050566          0.086875
# DailyRate                 0.010270   0.050566   1.000000          0.023364
# DistanceFromHome          0.022883   0.086875   0.023364          1.000000
# Education                 0.181464   0.041021   0.049667          0.012416
# EmployeeCount                  NaN        NaN        NaN               NaN
# EmployeeNumber            0.003173   0.026833   0.072425          0.008191
# EnvironmentSatisfaction   0.033375   0.119202   0.018301          0.022668
# HourlyRate                0.006313   0.018472   0.025172          0.056265
# JobInvolvement            0.042037   0.158768   0.057859          0.058609
# JobLevel                  0.512325   0.169121   0.009149          0.030509
# JobSatisfaction           0.021383   0.097518   0.032010          0.002253
# MonthlyIncome             0.503340   0.163709   0.015948          0.048151
# MonthlyRate               0.016969   0.025739   0.042087          0.026314
# NumCompaniesWorked        0.313343   0.037174   0.026531          0.021968
# PercentSalaryHike         0.025688   0.008138   0.031686          0.041837
# PerformanceRating         0.037771   0.005300   0.024503          0.034268
# RelationshipSatisfaction  0.061905   0.050263   0.023635          0.005861
# StockOptionLevel          0.006998   0.160597   0.042857          0.043912
# TotalWorkingYears         0.691968   0.178842   0.028833          0.025257
# TrainingTimesLastYear     0.002472   0.038728   0.004617          0.007631
# WorkLifeBalance           0.028193   0.064322   0.066313          0.053905
# YearsAtCompany            0.317744   0.133021   0.042520          0.029847
# YearsInCurrentRole        0.209906   0.159691   0.005374          0.004379
# YearsSinceLastPromotion   0.215766   0.031826   0.041213          0.008735
# YearsWithCurrManager      0.194178   0.151208   0.037282          0.004795
# ID                        0.002749   0.026794   0.072765          0.008636
#
#                           Education  EmployeeCount  EmployeeNumber  \
# Age                        0.181464            NaN        0.003173
# Attrition                  0.041021            NaN        0.026833
# DailyRate                  0.049667            NaN        0.072425
# DistanceFromHome           0.012416            NaN        0.008191
# Education                  1.000000            NaN        0.002240
# EmployeeCount                   NaN            NaN             NaN
# EmployeeNumber             0.002240            NaN        1.000000
# EnvironmentSatisfaction    0.006558            NaN        0.029648
# HourlyRate                 0.022398            NaN        0.024285
# JobInvolvement             0.028283            NaN        0.003322
# JobLevel                   0.098366            NaN        0.031621
# JobSatisfaction            0.003848            NaN        0.043556
# MonthlyIncome              0.098867            NaN        0.041926
# MonthlyRate                0.049857            NaN        0.010285
# NumCompaniesWorked         0.133409            NaN        0.003580
# PercentSalaryHike          0.018768            NaN        0.056774
# PerformanceRating          0.039675            NaN        0.057206
# RelationshipSatisfaction   0.014048            NaN        0.093246
# StockOptionLevel           0.003790            NaN        0.024540
# TotalWorkingYears          0.133525            NaN        0.018827
# TrainingTimesLastYear      0.036168            NaN        0.007704
# WorkLifeBalance            0.011091            NaN        0.028360
# YearsAtCompany             0.061348            NaN        0.012112
# YearsInCurrentRole         0.075898            NaN        0.000836
# YearsSinceLastPromotion    0.072333            NaN        0.005375
# YearsWithCurrManager       0.086565            NaN        0.010186
# ID                         0.001705            NaN        0.999796
#
#                           EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# Age                                      0.033375    0.006313        0.042037
# Attrition                                0.119202    0.018472        0.158768
# DailyRate                                0.018301    0.025172        0.057859
# DistanceFromHome                         0.022668    0.056265        0.058609
# Education                                0.006558    0.022398        0.028283
# EmployeeCount                                 NaN         NaN             NaN
# EmployeeNumber                           0.029648    0.024285        0.003322
# EnvironmentSatisfaction                  1.000000    0.066821        0.014838
# HourlyRate                               0.066821    1.000000        0.045250
# JobInvolvement                           0.014838    0.045250        1.000000
# JobLevel                                 0.014005    0.013305        0.007549
# JobSatisfaction                          0.017982    0.072199        0.037395
# MonthlyIncome                            0.000771    0.004524        0.006137
# MonthlyRate                              0.019339    0.026535        0.011343
# NumCompaniesWorked                       0.000308    0.023740        0.010136
# PercentSalaryHike                        0.063798    0.007174        0.022957
# PerformanceRating                        0.044733    0.009990        0.014805
# RelationshipSatisfaction                 0.011526    0.016492        0.061255
# StockOptionLevel                         0.020861    0.020385        0.043739
# TotalWorkingYears                        0.008940    0.010346        0.005842
# TrainingTimesLastYear                    0.036634    0.014123        0.030435
# WorkLifeBalance                          0.018968    0.002916        0.022140
# YearsAtCompany                           0.000121    0.018412        0.009283
# YearsInCurrentRole                       0.025088    0.033051        0.011350
# YearsSinceLastPromotion                  0.023509    0.042768        0.021055
# YearsWithCurrManager                     0.003313    0.030232        0.038344
# ID                                       0.028744    0.022999        0.003512
#
#                           ...  RelationshipSatisfaction  StockOptionLevel  \
# Age                       ...                  0.061905          0.006998
# Attrition                 ...                  0.050263          0.160597
# DailyRate                 ...                  0.023635          0.042857
# DistanceFromHome          ...                  0.005861          0.043912
# Education                 ...                  0.014048          0.003790
# EmployeeCount             ...                       NaN               NaN
# EmployeeNumber            ...                  0.093246          0.024540
# EnvironmentSatisfaction   ...                  0.011526          0.020861
# HourlyRate                ...                  0.016492          0.020385
# JobInvolvement            ...                  0.061255          0.043739
# JobLevel                  ...                  0.031862          0.013419
# JobSatisfaction           ...                  0.004539          0.025209
# MonthlyIncome             ...                  0.033579          0.008492
# MonthlyRate               ...                  0.013091          0.027881
# NumCompaniesWorked        ...                  0.038144          0.011965
# PercentSalaryHike         ...                  0.042330          0.010949
# PerformanceRating         ...                  0.007457          0.003638
# RelationshipSatisfaction  ...                  1.000000          0.042075
# StockOptionLevel          ...                  0.042075          1.000000
# TotalWorkingYears         ...                  0.040140          0.005594
# TrainingTimesLastYear     ...                  0.007827          0.027556
# WorkLifeBalance           ...                  0.010171          0.024220
# YearsAtCompany            ...                  0.027830          0.034629
# YearsInCurrentRole        ...                  0.010471          0.056891
# YearsSinceLastPromotion   ...                  0.042093          0.036154
# YearsWithCurrManager      ...                  0.001683          0.029358
# ID                        ...                  0.092574          0.024672
#
#                           TotalWorkingYears  TrainingTimesLastYear  \
# Age                                0.691968               0.002472
# Attrition                          0.178842               0.038728
# DailyRate                          0.028833               0.004617
# DistanceFromHome                   0.025257               0.007631
# Education                          0.133525               0.036168
# EmployeeCount                           NaN                    NaN
# EmployeeNumber                     0.018827               0.007704
# EnvironmentSatisfaction            0.008940               0.036634
# HourlyRate                         0.010346               0.014123
# JobInvolvement                     0.005842               0.030435
# JobLevel                           0.789603               0.007115
# JobSatisfaction                    0.040235               0.014605
# MonthlyIncome                      0.780190               0.001611
# MonthlyRate                        0.011111               0.016580
# NumCompaniesWorked                 0.250971               0.050191
# PercentSalaryHike                  0.052149               0.012951
# PerformanceRating                  0.027516               0.022443
# RelationshipSatisfaction           0.040140               0.007827
# StockOptionLevel                   0.005594               0.027556
# TotalWorkingYears                  1.000000               0.028268
# TrainingTimesLastYear              0.028268               1.000000
# WorkLifeBalance                    0.007360               0.046765
# YearsAtCompany                     0.632968               0.007723
# YearsInCurrentRole                 0.460833               0.034908
# YearsSinceLastPromotion            0.405928               0.000046
# YearsWithCurrManager               0.450119               0.021457
# ID                                 0.019201               0.006807
#
#                           WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Age                              0.028193        0.317744            0.209906
# Attrition                        0.064322        0.133021            0.159691
# DailyRate                        0.066313        0.042520            0.005374
# DistanceFromHome                 0.053905        0.029847            0.004379
# Education                        0.011091        0.061348            0.075898
# EmployeeCount                         NaN             NaN                 NaN
# EmployeeNumber                   0.028360        0.012112            0.000836
# EnvironmentSatisfaction          0.018968        0.000121            0.025088
# HourlyRate                       0.002916        0.018412            0.033051
# JobInvolvement                   0.022140        0.009283            0.011350
# JobLevel                         0.038443        0.546291            0.406993
# JobSatisfaction                  0.066238        0.030551            0.020956
# MonthlyIncome                    0.027060        0.528101            0.382471
# MonthlyRate                      0.030991        0.032269            0.020893
# NumCompaniesWorked               0.003022        0.100931            0.074283
# PercentSalaryHike                0.043728        0.057255            0.019608
# PerformanceRating                0.038055        0.025157            0.017597
# RelationshipSatisfaction         0.010171        0.027830            0.010471
# StockOptionLevel                 0.024220        0.034629            0.056891
# TotalWorkingYears                0.007360        0.632968            0.460833
# TrainingTimesLastYear            0.046765        0.007723            0.034908
# WorkLifeBalance                  1.000000        0.011040            0.026348
# YearsAtCompany                   0.011040        1.000000            0.761659
# YearsInCurrentRole               0.026348        0.761659            1.000000
# YearsSinceLastPromotion          0.007606        0.622171            0.551913
# YearsWithCurrManager             0.003349        0.760376            0.717550
# ID                               0.028986        0.011621            0.000047
#
#                           YearsSinceLastPromotion  YearsWithCurrManager  \
# Age                                      0.215766              0.194178
# Attrition                                0.031826              0.151208
# DailyRate                                0.041213              0.037282
# DistanceFromHome                         0.008735              0.004795
# Education                                0.072333              0.086565
# EmployeeCount                                 NaN                   NaN
# EmployeeNumber                           0.005375              0.010186
# EnvironmentSatisfaction                  0.023509              0.003313
# HourlyRate                               0.042768              0.030232
# JobInvolvement                           0.021055              0.038344
# JobLevel                                 0.358058              0.376563
# JobSatisfaction                          0.034739              0.046355
# MonthlyIncome                            0.349121              0.343414
# MonthlyRate                              0.021680              0.026640
# NumCompaniesWorked                       0.023271              0.093964
# PercentSalaryHike                        0.035975              0.032621
# PerformanceRating                        0.002459              0.002141
# RelationshipSatisfaction                 0.042093              0.001683
# StockOptionLevel                         0.036154              0.029358
# TotalWorkingYears                        0.405928              0.450119
# TrainingTimesLastYear                    0.000046              0.021457
# WorkLifeBalance                          0.007606              0.003349
# YearsAtCompany                           0.622171              0.760376
# YearsInCurrentRole                       0.551913              0.717550
# YearsSinceLastPromotion                  1.000000              0.497540
# YearsWithCurrManager                     0.497540              1.000000
# ID                                       0.005323              0.010620
#
#                                 ID
# Age                       0.002749
# Attrition                 0.026794
# DailyRate                 0.072765
# DistanceFromHome          0.008636
# Education                 0.001705
# EmployeeCount                  NaN
# EmployeeNumber            0.999796
# EnvironmentSatisfaction   0.028744
# HourlyRate                0.022999
# JobInvolvement            0.003512
# JobLevel                  0.032274
# JobSatisfaction           0.043152
# MonthlyIncome             0.042457
# MonthlyRate               0.010144
# NumCompaniesWorked        0.004285
# PercentSalaryHike         0.057322
# PerformanceRating         0.057851
# RelationshipSatisfaction  0.092574
# StockOptionLevel          0.024672
# TotalWorkingYears         0.019201
# TrainingTimesLastYear     0.006807
# WorkLifeBalance           0.028986
# YearsAtCompany            0.011621
# YearsInCurrentRole        0.000047
# YearsSinceLastPromotion   0.005323
# YearsWithCurrManager      0.010620
# ID                        1.000000
#
# [27 rows x 27 columns]

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Draw a scatter plot between between ```imdb_rating``` and ```audience_score```, and also fit a regression line.
# * Change the color of marker to red, size to 200, transparency to 0.3.

# %%
# Scatter plot to fit the regression line 
plt.figure(figsize=(20,20))
plt.scatter(movies.imdb_rating, movies.audience_score)

# %%
# Change marker of the scatter plot
plt.scatter(movies.imdb_rating, movies.audience_score, marker="*", color="red", alpha=0.3, s=200)

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw a scatter plot between between ```petal_length``` and ```petal_width``` and color it according to the ```species```.
# * Change the size of marker to 100 and place the legend in ```lower right```.

# %%
# library & dataset
dataset = pd.read_csv("iris.csv")
setosa=dataset[dataset['Species']=='Iris-setosa']
versicolor =dataset[dataset['Species']=='Iris-versicolor']
virginica =dataset[dataset['Species']=='Iris-virginica']
# Use the 'hue' argument to provide a factor variable
plt.figure()
fig,ax=plt.subplots(1,2,figsize=(21, 10))
setosa.plot(x="PetalLengthCm", y="PetalWidthCm", kind="scatter",ax=ax[1],label='setosa',color='r')
versicolor.plot(x="PetalLengthCm",y="PetalWidthCm",kind="scatter",ax=ax[1],label='versicolor',color='b')
virginica.plot(x="PetalLengthCm", y="PetalWidthCm", kind="scatter", ax=ax[1], label='virginica', color='g')
# Move the legend to an empty part of the plot
ax[0].legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),shadow=True)

# %% [markdown]
# ---
# ## Part 4 - Density Plots
# ---

# %% [markdown]
# ### Using density plots, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots for all the features ```sepal_width```, ```sepal_length```, ```petal_width```, and ```petal_length```. You can required to use subplots for plotting all the density plots.
# * Try drawing a [CDF](https://en.wikipedia.org/wiki/Cumulative_distribution_function) of these features. There is a [blog on medium](https://medium.com/@rishav.jnit/exploratory-data-analysis-eda-on-iris-dataset-using-python-cadd850c1fc6) on how to plot CDF. It will be covered in tutorial.

# %%
# library and dataset 
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# 13    14            4.3           3.0            1.1           0.1
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# 16    17            5.4           3.9            1.3           0.4
# 17    18            5.1           3.5            1.4           0.3
# 18    19            5.7           3.8            1.7           0.3
# 19    20            5.1           3.8            1.5           0.3
# 20    21            5.4           3.4            1.7           0.2
# 21    22            5.1           3.7            1.5           0.4
# 22    23            4.6           3.6            1.0           0.2
# 23    24            5.1           3.3            1.7           0.5
# 24    25            4.8           3.4            1.9           0.2
# 25    26            5.0           3.0            1.6           0.2
# 26    27            5.0           3.4            1.6           0.4
# 27    28            5.2           3.5            1.5           0.2
# 28    29            5.2           3.4            1.4           0.2
# 29    30            4.7           3.2            1.6           0.2
# ..   ...            ...           ...            ...           ...
# 120  121            6.9           3.2            5.7           2.3
# 121  122            5.6           2.8            4.9           2.0
# 122  123            7.7           2.8            6.7           2.0
# 123  124            6.3           2.7            4.9           1.8
# 124  125            6.7           3.3            5.7           2.1
# 125  126            7.2           3.2            6.0           1.8
# 126  127            6.2           2.8            4.8           1.8
# 127  128            6.1           3.0            4.9           1.8
# 128  129            6.4           2.8            5.6           2.1
# 129  130            7.2           3.0            5.8           1.6
# 130  131            7.4           2.8            6.1           1.9
# 131  132            7.9           3.8            6.4           2.0
# 132  133            6.4           2.8            5.6           2.2
# 133  134            6.3           2.8            5.1           1.5
# 134  135            6.1           2.6            5.6           1.4
# 135  136            7.7           3.0            6.1           2.3
# 136  137            6.3           3.4            5.6           2.4
# 137  138            6.4           3.1            5.5           1.8
# 138  139            6.0           3.0            4.8           1.8
# 139  140            6.9           3.1            5.4           2.1
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# 9       Iris-setosa
# 10      Iris-setosa
# 11      Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# 16      Iris-setosa
# 17      Iris-setosa
# 18      Iris-setosa
# 19      Iris-setosa
# 20      Iris-setosa
# 21      Iris-setosa
# 22      Iris-setosa
# 23      Iris-setosa
# 24      Iris-setosa
# 25      Iris-setosa
# 26      Iris-setosa
# 27      Iris-setosa
# 28      Iris-setosa
# 29      Iris-setosa
# ..              ...
# 120  Iris-virginica
# 121  Iris-virginica
# 122  Iris-virginica
# 123  Iris-virginica
# 124  Iris-virginica
# 125  Iris-virginica
# 126  Iris-virginica
# 127  Iris-virginica
# 128  Iris-virginica
# 129  Iris-virginica
# 130  Iris-virginica
# 131  Iris-virginica
# 132  Iris-virginica
# 133  Iris-virginica
# 134  Iris-virginica
# 135  Iris-virginica
# 136  Iris-virginica
# 137  Iris-virginica
# 138  Iris-virginica
# 139  Iris-virginica
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
sns.distplot(df['SepalWidthCm'], hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
sns.distplot(df['SepalLengthCm'], hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
sns.distplot(df['PetalWidthCm'], hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
sns.distplot(df['PetalLengthCm'], hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
counts, bin_edges = np.histogram(df['petal length (cm)'], bins=10, density = True)
pdf = counts/(sum(counts))

cdf = np.cumsum(pdf)
plt.grid()
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)

# %%
counts, bin_edges = np.histogram(df['sepal length (cm)'], bins=10, density = True)
pdf = counts/(sum(counts))

cdf = np.cumsum(pdf)
plt.grid()
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)

# %%
counts, bin_edges = np.histogram(df['petal width (cm)'], bins=10, density = True)
pdf = counts/(sum(counts))

cdf = np.cumsum(pdf)
plt.grid()
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)

# %%
counts, bin_edges = np.histogram(df['sepal width (cm)'], bins=10, density = True)
pdf = counts/(sum(counts))

cdf = np.cumsum(pdf)
plt.grid()
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)

# %% [markdown]
# ### Using violin plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots of ```species``` versus ```sepal_length```.
# * Assign each group a color like
#
#     * versicolor - green,
#     * setosa - blue,
#     * virginica - m

# %%
# Draw the normal violin plots 
sns.violinplot(x="SepalLengthCm", y="Species", data=df)

# %%
# Change the color of each group
